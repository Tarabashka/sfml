# %% [markdown]
# # SkillFactory
# ## Введение в ML, введение в sklearn

# %% [markdown]
# В этом задании мы с вами рассмотрим данные с конкурса [Задача предсказания отклика клиентов ОТП Банка](http://www.machinelearning.ru/wiki/index.php?title=%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BF%D1%80%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BE%D1%82%D0%BA%D0%BB%D0%B8%D0%BA%D0%B0_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2_%D0%9E%D0%A2%D0%9F_%D0%91%D0%B0%D0%BD%D0%BA%D0%B0_%28%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%29)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)

# %% [markdown]
# ### Грузим данные

# %% [markdown]
# Считаем описание данных

# %%
df_descr = pd.read_csv('data/otp_description.csv', sep='\t', encoding='utf8')

# %%
df_descr
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                          AGE
# 2            SOCSTATUS_WORK_FL
# 3            SOCSTATUS_PENS_FL
# 4                       GENDER
# 5                  CHILD_TOTAL
# 6                   DEPENDANTS
# 7                    EDUCATION
# 8               MARITAL_STATUS
# 9                 GEN_INDUSTRY
# 10                   GEN_TITLE
# 11                ORG_TP_STATE
# 12             ORG_TP_FCAPITAL
# 13                     JOB_DIR
# 14               FAMILY_INCOME
# 15             PERSONAL_INCOME
# 16        REG_ADDRESS_PROVINCE
# 17       FACT_ADDRESS_PROVINCE
# 18     POSTAL_ADDRESS_PROVINCE
# 19                 TP_PROVINCE
# 20                   REGION_NM
# 21                 REG_FACT_FL
# 22                FACT_POST_FL
# 23                 REG_POST_FL
# 24            REG_FACT_POST_FL
# 25         REG_FACT_POST_TP_FL
# 26              FL_PRESENCE_FL
# 27                    OWN_AUTO
# 28                 AUTO_RUS_FL
# 29              HS_PRESENCE_FL
# 30             COT_PRESENCE_FL
# 31             GAR_PRESENCE_FL
# 32            LAND_PRESENCE_FL
# 33                      CREDIT
# 34                        TERM
# 35                 FST_PAYMENT
# 36              DL_DOCUMENT_FL
# 37             GPF_DOCUMENT_FL
# 38            FACT_LIVING_TERM
# 39                   WORK_TIME
# 40               FACT_PHONE_FL
# 41                REG_PHONE_FL
# 42                GEN_PHONE_FL
# 43              LOAN_NUM_TOTAL
# 44             LOAN_NUM_CLOSED
# 45               LOAN_NUM_PAYM
# 46                LOAN_DLQ_NUM
# 47                LOAN_MAX_DLQ
# 48            LOAN_AVG_DLQ_AMT
# 49            LOAN_MAX_DLQ_AMT
# 50  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1                                     возраст клиента
# 2   социальный статус клиента относительно работы ...
# 3   социальный статус клиента относительно пенсии ...
# 4                 пол клиента (1- женщины, 0-мужчины)
# 5                            количество детей клиента
# 6                       количество иждивенцев клиента
# 7                                         образование
# 8                                  семейное положение
# 9                              отрасль работы клиента
# 10                                          должность
# 11                       форма собственности компании
# 12                  отношение к иностранному капиталу
# 13          направление деятельности в нутри компании
# 14               семейный доход (несколько категорий)
# 15                    личный доход клиента (в рублях)
# 16                        область регистрации клиента
# 17            область фактического пребывания клиента
# 18                             почтовый адрес область
# 19  область торговой точки, где клиент брал послед...
# 20                                          регион РФ
# 21  адрес регистрации и адрес фактического пребыва...
# 22  адрес фактического пребывания клиента и его по...
# 23  адрес регистрации клиента и его почтовый адрес...
# 24  почтовый, фактический и адрес регистрации совп...
# 25  область регистрации, фактического пребывания, ...
# 26  наличие в собственности квартиры (1 - есть, 0 ...
# 27                кол-во автомобилей в собственности
# 28  наличие в собственности автомобиля российского...
# 29  наличие в собственности загородного дома (1 - ...
# 30  наличие в собственности котеджа (1 - есть, 0 -...
# 31  наличие в собственности гаража (1 - есть, 0 - ...
# 32  наличие в собственности земельного участка (1 ...
# 33        сумма последнего кредита клиента (в рублях)
# 34                                       срок кредита
# 35                    первоначальный взнос (в рублях)
# 36  в анкете клиент указал водительское удостовере...
# 37  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 38  количество месяцев проживания по месту фактиче...
# 39          время работы на текущем месте (в месяцах)
# 40  наличие в заявке телефона по фактическому мест...
# 41     наличие в заявке телефона по месту регистрации
# 42                 наличие в заявке рабочего телефона
# 43                            количество ссуд клиента
# 44                 количество погашенных ссуд клиента
# 45         количество платежей, которые сделал клиент
# 46          количество просрочек, допущенных клиентом
# 47  номер максимальной просрочки, допущенной клиентом
# 48                 средняя сумма просрочки (в рублях)
# 49            максимальная сумма просрочки (в рублях)
# 50  количество уже утилизированных карт ( если пус...

# %% [markdown]
# Считаем обучающую выборки и тестовую (которую мы как бы не видим)

# %%
df_train = pd.read_csv('data/otp_train.csv', sep='\t', encoding='utf8')

# %%
df_train.shape
# Out:
# (15223, 53)

# %%
df_test = pd.read_csv('data/otp_test.csv', sep='\t', encoding='utf8')

# %%
df_test.shape
# Out:
# (14910, 53)

# %%
df_train.head()
# Out:
#    AGREEMENT_RK  TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59910150       0   49                  1                  0       1
# 1      59910230       0   32                  1                  0       1
# 2      59910525       0   52                  1                  0       1
# 3      59910803       0   39                  1                  0       1
# 4      59911781       0   30                  1                  0       0
#
#    CHILD_TOTAL  DEPENDANTS            EDUCATION  MARITAL_STATUS  \
# 0            2           1  Среднее специальное  Состою в браке
# 1            3           3              Среднее  Состою в браке
# 2            4           0     Неполное среднее  Состою в браке
# 3            1           1               Высшее  Состою в браке
# 4            0           0              Среднее  Состою в браке
#
#              ...             REG_PHONE_FL GEN_PHONE_FL LOAN_NUM_TOTAL  \
# 0            ...                        0            1              1
# 1            ...                        0            1              1
# 2            ...                        0            1              2
# 3            ...                        1            1              1
# 4            ...                        0            1              2
#
#   LOAN_NUM_CLOSED LOAN_NUM_PAYM LOAN_DLQ_NUM LOAN_MAX_DLQ  LOAN_AVG_DLQ_AMT  \
# 0               1             6            2            1              1580
# 1               1             6            1            1              4020
# 2               1            11            0            0                 0
# 3               1             6            3            1  1589,92333333333
# 4               1            16            2            1           1152,15
#
#   LOAN_MAX_DLQ_AMT PREVIOUS_CARD_NUM_UTILIZED
# 0             1580                        NaN
# 1             4020                        NaN
# 2                0                        NaN
# 3             1590                        NaN
# 4             2230                        NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Объединим две выборки
#
# Так как пока мы пока не умеем работать sklearn  Pipeline, то для того, чтобы после предобработки столбцы в двух выборках находились на своих местах.
#
# Для того, чтобы в дальнейшем отделить их введем новый столбец "sample"

# %%
df_train.loc[:, 'sample'] = 'train'
df_test.loc[:, 'sample'] = 'test'

# %%
df = df_test.append(df_train).reset_index(drop=True)

# %%
df.shape
# Out:
# (30133, 53)

# %% [markdown]
# ### Чуть-чуть посмотрим на данные

# %% [markdown]
# Посмотрим типы данных и их заполняемость

# %%
df.info()
LOAN_MAX_DLQ_AM
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# sample                        30133 non-null object
# dtypes: float64(2), int64(32), object(19)
# memory usage: 12.2+ MB

# %% [markdown]
# Видим, что часть данных - object, скорее всего стоки.
#
#
# Давайте выведем эти значения для каждого столбца

# %%
for i in df_train.columns: # перебираем все столбцы
    if str(df_train[i].dtype) == 'object': # если тип столбца - object
        print('='*10)
        print(i) # выводим название столбца
        print(set(df_train[i])) # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print('\n') # выводим пустую строку
# Out:
# ==========
# EDUCATION
# {'Высшее', 'Неполное среднее', 'Неоконченное высшее', 'Ученая степень', 'Среднее специальное', 'Среднее', 'Два и более высших образования'}
#
#
# ==========
# MARITAL_STATUS
# {'Вдовец/Вдова', 'Не состоял в браке', 'Разведен(а)', 'Гражданский брак', 'Состою в браке'}
#
#
# ==========
# GEN_INDUSTRY
# {nan, 'Информационные услуги', 'Ресторанный бизнес/Общественное питание', 'Торговля', 'Образование', 'Энергетика', 'Логистика', 'Подбор персонала', 'Наука', 'Сборочные производства', 'Коммунальное хоз-во/Дорожные службы', 'Другие сферы', 'Юридические услуги/нотариальные услуги', 'Строительство', 'Банк/Финансы', 'Химия/Парфюмерия/Фармацевтика', 'Салоны красоты и здоровья', 'Металлургия/Промышленность/Машиностроение', 'ЧОП/Детективная д-ть', 'Развлечения/Искусство', 'Туризм', 'Страхование', 'Маркетинг', 'СМИ/Реклама/PR-агенства', 'Недвижимость', 'Государственная служба', 'Нефтегазовая промышленность', 'Сельское хозяйство', 'Управляющая компания', 'Здравоохранение', 'Информационные технологии', 'Транспорт'}
#
#
# ==========
# GEN_TITLE
# {nan, 'Руководитель низшего звена', 'Рабочий', 'Партнер', 'Служащий', 'Военнослужащий по контракту', 'Работник сферы услуг', 'Другое', 'Индивидуальный предприниматель', 'Руководитель среднего звена', 'Высококвалифиц. специалист', 'Руководитель высшего звена', 'Специалист'}
#
#
# ==========
# ORG_TP_STATE
# {nan, 'Частная компания', 'Государственная комп./учреж.', 'Частная ком. с инос. капиталом', 'Индивидуальный предприниматель', 'Некоммерческая организация'}
#
#
# ==========
# ORG_TP_FCAPITAL
# {nan, 'Без участия', 'С участием'}
#
#
# ==========
# JOB_DIR
# {nan, 'Бухгалтерия, финансы, планир.', 'Реклама и маркетинг', 'Служба безопасности', 'Пр-техн. обесп. и телеком.', 'Снабжение и сбыт', 'Кадровая служба и секретариат', 'Юридическая служба', 'Участие в основ. деятельности', 'Адм-хоз. и трансп. службы', 'Вспомогательный техперсонал'}
#
#
# ==========
# FAMILY_INCOME
# {'свыше 50000 руб.', 'от 10000 до 20000 руб.', 'от 20000 до 50000 руб.', 'от 5000 до 10000 руб.', 'до 5000 руб.'}
#
#
# ==========
# PERSONAL_INCOME
# {'13900', '5582', '9700', '5300', '5680', '4300', '43000', '9100', '19000', '21000', '40000', '26000', '50000', '6200', '13400', '19300', '17600', '12900', '9200', '4600', '3700', '17800', '14500', '9900', '5200', '45000', '33000', '23500', '15300', '12000', '5446', '12300', '12100', '12400', '8600', '4340', '8900', '6800', '220000', '2100', '46000', '7800', '19600', '10800', '42500', '28300', '5339', '16050', '11000', '23000', '13150', '4200', '13800', '75000', '8400', '9628', '23100', '29000', '19500', '6100', '250000', '8800', '6180', '70000', '26500', '52000', '32640', '9800', '9400', '8500', '8250', '13000', '9500', '17200', '3600', '6299,19', '35000', '170000', '7100', '18000', '4000', '42000', '8066', '13500', '48000', '60000', '17000', '15560', '5000', '5790', '47000', '5230', '49000', '5360', '65000', '55000', '3800', '6608', '23800', '7500', '18600', '4515', '10400', '5800', '28000', '12500', '51000', '11800', '19800', '8350', '25000', '12650', '37000', '8700', '13200', '5050', '11400', '15500', '7220', '30000', '7200', '7300', '3300', '20000', '7101', '15000', '7550', '5460', '6400', '6000', '5700', '29500', '12600', '22955', '5100', '92000', '12800', '24000', '4100', '5350', '44000', '10600', '3100', '13160', '16000', '150000', '32000', '24500', '9600', '4900', '77000', '38000', '25800', '14700', '7830', '13700', '3000', '41000', '24800', '4360', '17404', '3200', '16900', '14000', '4400', '9330', '160000', '9340', '7000', '27300', '17500', '2000', '14358', '4330', '29800', '34000', '14800', '7050', '22000', '10500', '10100', '9240', '20500', '6359', '18700', '22500', '8000', '11700', '10900', '10700', '2300', '11500', '7850', '7700', '14300', '4800', '11200', '4590', '8100', '10300', '15400', '13300', '100000', '11300', '41900', '18500', '1950', '9000', '5400', '36000', '11600', '8300', '18200', '31000', '5500', '110000', '67000', '7251', '6700', '5425', '21500', '12700', '68000', '16800', '11640', '7600', '7650', '6670', '7900', '16500', '19700', '20646,16', '2800', '5600', '3400', '16700', '11900', '5088', '10000', '5900', '3500', '13600', '67700', '4700', '3900', '7640', '8726', '16100', '6500', '6300', '27000', '15600', '53000', '17900', '13450', '7250', '21800', '54000', '6900', '7400', '80000', '6600', '24', '16200', '9300', '17700', '15380', '4950', '4500', '39000', '56000', '8200', '10200', '15200'}
#
#
# ==========
# REG_ADDRESS_PROVINCE
# {'Тверская область', 'Марийская республика', 'Кировская область', 'Тамбовская область', 'Якутия', 'Санкт-Петербург', 'Ростовская область', 'Бурятия', 'Вологодская область', 'Саратовская область', 'Ханты-Мансийский АО', 'Иркутская область', 'Еврейская АО', 'Калужская область', 'Самарская область', 'Хакасия', 'Ульяновская область', 'Рязанская область', 'Усть-Ордынский Бурятский АО', 'Воронежская область', 'Тюменская область', 'Владимирская область', 'Псковская область', 'Омская область', 'Приморский край', 'Мурманская область', 'Нижегородская область', 'Оренбургская область', 'Москва', 'Амурская область', 'Кемеровская область', 'Пензенская область', 'Коми', 'Новосибирская область', 'Ямало-Ненецкий АО', 'Эвенкийский АО', 'Брянская область', 'Кабардино-Балкария', 'Алтайский край', 'Карелия', 'Липецкая область', 'Хабаровский край', 'Московская область', 'Белгородская область', 'Архангельская область', 'Ивановская область', 'Мордовская республика', 'Орловская область', 'Ярославская область', 'Челябинская область', 'Тульская область', 'Магаданская область', 'Чувашия', 'Адыгея', 'Костромская область', 'Новгородская область', 'Ставропольский край', 'Татарстан', 'Томская область', 'Калмыкия', 'Краснодарский край', 'Камчатская область', 'Горный Алтай', 'Удмуртия', 'Агинский Бурятский АО', 'Дагестан', 'Курская область', 'Астраханская область', 'Курганская область', 'Свердловская область', 'Читинская область', 'Калининградская область', 'Северная Осетия', 'Ленинградская область', 'Волгоградская область', 'Пермская область', 'Башкирия', 'Смоленская область', 'Карачаево-Черкесия', 'Сахалинская область', 'Красноярский край'}
#
#
# ==========
# FACT_ADDRESS_PROVINCE
# {'Тверская область', 'Марийская республика', 'Кировская область', 'Тамбовская область', 'Якутия', 'Санкт-Петербург', 'Ростовская область', 'Бурятия', 'Вологодская область', 'Саратовская область', 'Ханты-Мансийский АО', 'Иркутская область', 'Еврейская АО', 'Калужская область', 'Самарская область', 'Хакасия', 'Ульяновская область', 'Рязанская область', 'Усть-Ордынский Бурятский АО', 'Воронежская область', 'Тюменская область', 'Владимирская область', 'Псковская область', 'Омская область', 'Приморский край', 'Мурманская область', 'Нижегородская область', 'Оренбургская область', 'Москва', 'Амурская область', 'Кемеровская область', 'Пензенская область', 'Коми', 'Новосибирская область', 'Ямало-Ненецкий АО', 'Эвенкийский АО', 'Брянская область', 'Кабардино-Балкария', 'Алтайский край', 'Карелия', 'Липецкая область', 'Хабаровский край', 'Московская область', 'Белгородская область', 'Чувашия', 'Ивановская область', 'Мордовская республика', 'Орловская область', 'Ярославская область', 'Челябинская область', 'Тульская область', 'Магаданская область', 'Костромская область', 'Адыгея', 'Новгородская область', 'Ставропольский край', 'Татарстан', 'Томская область', 'Калмыкия', 'Краснодарский край', 'Камчатская область', 'Горный Алтай', 'Удмуртия', 'Агинский Бурятский АО', 'Дагестан', 'Курская область', 'Архангельская область', 'Астраханская область', 'Курганская область', 'Свердловская область', 'Читинская область', 'Калининградская область', 'Северная Осетия', 'Ленинградская область', 'Волгоградская область', 'Пермская область', 'Башкирия', 'Смоленская область', 'Карачаево-Черкесия', 'Сахалинская область', 'Красноярский край'}
#
#
# ==========
# POSTAL_ADDRESS_PROVINCE
# {'Тверская область', 'Марийская республика', 'Кировская область', 'Тамбовская область', 'Якутия', 'Санкт-Петербург', 'Ростовская область', 'Бурятия', 'Вологодская область', 'Саратовская область', 'Ханты-Мансийский АО', 'Иркутская область', 'Еврейская АО', 'Калужская область', 'Самарская область', 'Хакасия', 'Ульяновская область', 'Рязанская область', 'Усть-Ордынский Бурятский АО', 'Воронежская область', 'Тюменская область', 'Владимирская область', 'Псковская область', 'Омская область', 'Приморский край', 'Мурманская область', 'Нижегородская область', 'Оренбургская область', 'Москва', 'Амурская область', 'Кемеровская область', 'Пензенская область', 'Коми', 'Новосибирская область', 'Ямало-Ненецкий АО', 'Эвенкийский АО', 'Брянская область', 'Кабардино-Балкария', 'Алтайский край', 'Карелия', 'Липецкая область', 'Хабаровский край', 'Московская область', 'Белгородская область', 'Чувашия', 'Ивановская область', 'Мордовская республика', 'Орловская область', 'Ярославская область', 'Челябинская область', 'Тульская область', 'Магаданская область', 'Костромская область', 'Адыгея', 'Новгородская область', 'Ставропольский край', 'Татарстан', 'Томская область', 'Калмыкия', 'Краснодарский край', 'Камчатская область', 'Горный Алтай', 'Удмуртия', 'Агинский Бурятский АО', 'Курская область', 'Архангельская область', 'Астраханская область', 'Курганская область', 'Свердловская область', 'Читинская область', 'Калининградская область', 'Северная Осетия', 'Ленинградская область', 'Волгоградская область', 'Пермская область', 'Башкирия', 'Смоленская область', 'Карачаево-Черкесия', 'Сахалинская область', 'Красноярский край'}
#
#
# ==========
# TP_PROVINCE
# {nan, 'Тверская область', 'Марийская республика', 'Кировская область', 'Тамбовская область', 'Якутия', 'Санкт-Петербург', 'Ростовская область', 'Бурятия', 'Вологодская область', 'Саратовская область', 'Ханты-Мансийский АО', 'Иркутская область', 'Еврейская АО', 'Калужская область', 'Самарская область', 'Ульяновская область', 'Рязанская область', 'Воронежская область', 'Тюменская область', 'Владимирская область', 'Псковская область', 'Омская область', 'Приморский край', 'Мурманская область', 'Нижегородская область', 'Оренбургская область', 'Москва', 'Амурская область', 'Кемеровская область', 'Пензенская область', 'Коми', 'Новосибирская область', 'Брянская область', 'Кабардино-Балкария', 'Алтайский край', 
140', '3890', '1070,05', '2102,75', '1650,53', '2732,2', '1490', '2119,77', '791,98', '1939,61', '631', '2365,47', '957,63', '1170', '4884,95', '769,43', '2429,09', '1440', '2790', '1007,8', '4770', '1309,89', '957,4', '4940', '2154,02', '1180', '2262,12', '7010', '1069,6', '948,58', '600,93', '749,82', '1529,06', '3590', '62,46', '2630', '3600', '1670', '619,73', '673,89', '2969,75', '798,53', '970', '2880', '1300', '1140', '2005,15', '1450', '1317,06', '1140,2', '892,18', '3127,19', '2349,51', '1620', '2569,05', '700', '2130', '5470', '2050', '1986,88', '976,68', '3635,77', '4158,85', '5550', '4490', '1710', '5030', '1610', '2573,8', '3780', '1093,75', '2490', '1344,33', '2740', '4190', '3501,45', '1139,49', '370,77', '324,16', '1102,7', '1059,47', '2760', '2375,59', '518,9', '2370', '1250', '1840', '1418,86', '2590', '2361,22', '1957,21', '1266,34', '887,79', '5110', '1015', '1789,04', '768,97', '2210', '1391,47', '1768,07', '846,74', '1094', '2163,94', '269,51', '355,04', '549,88', '680', '2247,51', '3410', '2000', '789,23', '802,36', '2755,21', '3490', '3260', '4020', '1848,05', '990,85', '1065,62', '3770', '3702,8', '2549,52', '1190', '5580', '3560', '3520', '776,3', '1439,94', '1402,43', '1530', '1105,07', '1420', '2989,98', '827,57', '2080', '1730', '4446,3', '904,08', '1200', '2140', '262 ...
#
#
# ==========
# sample
# {'train'}

# %% [markdown]
# Mожно заметить что некоторые переменные, которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа, но по какой-то причине были распознаны как строки
#
# Причина же что использовалась запятая для разделения не целой части числа..

# %% [markdown]
# Перекодировать их можно например так:

# %%
df['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')
# Out:
# 0         7000.0
# 1         4100.0
# 2        40000.0
# 3        20000.0
# 4        17000.0
# 5         7000.0
# 6        10000.0
# 7         7500.0
# 8         9000.0
# 9         4000.0
# 10       15000.0
# 11       12000.0
# 12        8000.0
# 13       20000.0
# 14       18500.0
# 15       14000.0
# 16        6000.0
# 17        9000.0
# 18        5000.0
# 19       15000.0
# 20        6100.0
# 21       22180.0
# 22        9000.0
# 23        8700.0
# 24        7000.0
# 25        6000.0
# 26       15000.0
# 27       12000.0
# 28       11000.0
# 29        8000.0
#           ...
# 30103    12000.0
# 30104    10000.0
# 30105    10000.0
# 30106     8000.0
# 30107    11000.0
# 30108     7000.0
# 30109    10000.0
# 30110     8000.0
# 30111    25000.0
# 30112    10000.0
# 30113    12000.0
# 30114     7000.0
# 30115    12000.0
# 30116    14500.0
# 30117    12000.0
# 30118     8000.0
# 30119     7000.0
# 30120    10000.0
# 30121    10000.0
# 30122    10000.0
# 30123    15000.0
# 30124     8100.0
# 30125     9500.0
# 30126    13000.0
# 30127    10000.0
# 30128    12000.0
# 30129    10000.0
# 30130     6000.0
# 30131     4500.0
# 30132    20000.0
# Name: PERSONAL_INCOME, Length: 30133, dtype: float64

# %% [markdown]
# Такой эффект наблюдается в столбцах `PERSONAL_INCOME`, `CREDIT`, `FST_PAYMENT`, `LOAN_AVG_DLQ_AMT`, `LOAN_MAX_DLQ_AMT`

# %% [markdown]
# ### Теперь ваше небольшое исследование

# %% [markdown]
# #### Задание 1. Есть ли пропуски в данных? Что с ними сделать?
#
# (единственного верного ответа нет - аргументируйте)

# %%
## CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT - пропусков нет, но нужно также заменить , на .

# %% [markdown]
# #### Задание 2. Есть ли категориальные признаки? Что с ними делать?

# %%
## EDUCATION, MARITAL_STATUS, GEN_INDUSTRY, GEN_TITLE, ORG_TP_STATE, ORG_TP_FCAPITAL, JOB_DIR, FAMILY_INCOME, REG_ADDRESS_PROVINCE, FACT_ADDRESS_PROVINCE, POSTAL_ADDRESS_PROVINCE, TP_PROVINCE, REGION_NM относятся к категориальным признакам и их нужно кодировать

# %% [markdown]
# #### Задание 3. Фунция предобработки

# %% [markdown]
# Напишите функцию, которая бы
#
# * Удаляло идентификатор `AGREEMENT_RK`
# * Избавлялась от проблем с '.' и ',' в стобцах PERSONAL_INCOME, CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT
# * Что-то делала с пропусками
# * Кодировала категориальные признаки
#
# В результате, ваш датафрейм должен содержать только числа и не содержать пропусков!

# %%
def preproc_data(df_input):
    df_output = df_input.copy()
    df_output = df_output.drop(['AGREEMENT_RK', 'FACT_ADDRESS_PROVINCE', 'POSTAL_ADDRESS_PROVINCE', 'TP_PROVINCE', 'REGION_NM'], axis=1)
    list_change = ['PERSONAL_INCOME', 'CREDIT', 'FST_PAYMENT', 'LOAN_AVG_DLQ_AMT', 'LOAN_MAX_DLQ_AMT']
    for i in list_change: # заменяем , на . во всех столбцах из списка
        df_output[i] = df_output[i].map(lambda x: x.replace(',', '.')).astype('float')
    df_output = df_output.fillna(0) # упрощенно пока вставляем нули в nan. сделаем лучше чистку через среднее и пол
    ##df_output = df_output.dropna() # плохо работает так как остается только около 550 замеров
    df_output = pd.get_dummies(df_output, columns=['EDUCATION', 'MARITAL_STATUS', 'GEN_INDUSTRY', 'GEN_TITLE', 'ORG_TP_STATE', 'ORG_TP_FCAPITAL', 'JOB_DIR', 'FAMILY_INCOME', 'REG_ADDRESS_PROVINCE'])
    return df_output

# %%
df_preproc = df.pipe(preproc_data)

df_train_preproc = df_preproc.query('sample == "train"').drop(['sample'], axis=1)
df_test_preproc = df_preproc.query('sample == "test"').drop(['sample'], axis=1)

# %%
df_preproc.T
# Out:
#                                                    0     1      2      3      \
# TARGET                                                 0     0      0      0
# AGE                                                   30    48     35     22
# SOCSTATUS_WORK_FL                                      1     0      1      1
# SOCSTATUS_PENS_FL                                      0     1      0      0
# GENDER                                                 1     1      0      0
# CHILD_TOTAL                                            1     0      1      0
# DEPENDANTS                                             1     0      0      0
# PERSONAL_INCOME                                     7000  4100  40000  20000
# REG_FACT_FL                                            0     1      1      1
# FACT_POST_FL                                           1     1      1      1
# REG_POST_FL                                            0     1      1      1
# REG_FACT_POST_FL                                       0     1      1      1
# REG_FACT_POST_TP_FL                                    1     1      1      1
# FL_PRESENCE_FL                                         1     0      0      1
# OWN_AUTO                                               0     0      1      0
# AUTO_RUS_FL                                            0     0      1      0
# HS_PRESENCE_FL                                         0     1      0      0
# COT_PRESENCE_FL                                        0     0      0      0
# GAR_PRESENCE_FL                                        0     1      0      0
# LAND_PRESENCE_FL                                       0     0      0      0
# CREDIT                                            3016.8  6000  10000   5175
# TERM                                                   5     6      6      4
# FST_PAYMENT                                        335.2  2000   2490    575
# DL_DOCUMENT_FL                                         0     0      0      0
# GPF_DOCUMENT_FL                                        0     1      0      0
# FACT_LIVING_TERM                                      96   299     19    252
# WORK_TIME                                             39     0    156      9
# FACT_PHONE_FL                                          1     0      1      1
# REG_PHONE_FL                                           0     0      0      0
# GEN_PHONE_FL                                           1     0      1      1
# ...                                                  ...   ...    ...    ...
# REG_ADDRESS_PROVINCE_Псковская область                 0     0      0      0
# REG_ADDRESS_PROVINCE_Ростовская область                0     0      0      0
# REG_ADDRESS_PROVINCE_Рязанская область                 0     0      0      0
# REG_ADDRESS_PROVINCE_Самарская область                 0     0      0      0
# REG_ADDRESS_PROVINCE_Санкт-Петербург                   0     0      0      0
# REG_ADDRESS_PROVINCE_Саратовская область               0     0      0      0
# REG_ADDRESS_PROVINCE_Сахалинская область               0     0      0      0
# REG_ADDRESS_PROVINCE_Свердловская область              0     0      0      0
# REG_ADDRESS_PROVINCE_Северная Осетия                   0     0      0      0
# REG_ADDRESS_PROVINCE_Смоленская область                0     0      0      0
# REG_ADDRESS_PROVINCE_Ставропольский край               0     0      0      0
# REG_ADDRESS_PROVINCE_Тамбовская область                0     0      0      0
# REG_ADDRESS_PROVINCE_Татарстан                         0     0      0      0
# REG_ADDRESS_PROVINCE_Тверская область                  0     0      0      0
# REG_ADDRESS_PROVINCE_Томская область                   0     0      0      0
# REG_ADDRESS_PROVINCE_Тульская область                  0     0      0      0
# REG_ADDRESS_PROVINCE_Тюменская область                 0     0      0      0
# REG_ADDRESS_PROVINCE_Удмуртия                          0     0      0      0
# REG_ADDRESS_PROVINCE_Ульяновская область               0     0      0      0
# REG_ADDRESS_PROVINCE_Усть-Ордынский Бурятский АО       0     0      0      0
# REG_ADDRESS_PROVINCE_Хабаровский край                  0     0      0      0
# REG_ADDRESS_PROVINCE_Хакасия                           0     0      0      0
# REG_ADDRESS_PROVINCE_Ханты-Мансийский АО               0     0      0      0
# REG_ADDRESS_PROVINCE_Челябинская область               0     0      0      0
# REG_ADDRESS_PROVINCE_Читинская область                 0     0      0      1
# REG_ADDRESS_PROVINCE_Чувашия                           0     0      0      0
# REG_ADDRESS_PROVINCE_Эвенкийский АО                    0     0      0      0
# REG_ADDRESS_PROVINCE_Якутия                            0     0      0      0
# REG_ADDRESS_PROVINCE_Ямало-Ненецкий АО                 0     0      0      0
# REG_ADDRESS_PROVINCE_Ярославская область               0     0      0      0
#
#                                                   4        5      6     7      \
# TARGET                                                0        0      0     0
# AGE                                                  27       44     57    33
# SOCSTATUS_WORK_FL                                     1        0      1     1
# SOCSTATUS_PENS_FL                                     0        1      0     0
# GENDER                                                1        0      1     1
# CHILD_TOTAL                                           2        2      0     2
# DEPENDANTS                                            2        2      0     2
# PERSONAL_INCOME                                   17000     7000  10000  7500
# REG_FACT_FL                                           1        1      1     1
# FACT_POST_FL                                          1        1      1     1
# REG_POST_FL                                           1        1      1     1
# REG_FACT_POST_FL                                      1        1      1     1
# REG_FACT_POST_TP_FL                                   1        1      1     1
# FL_PRESENCE_FL                                        0        0      0     1
# OWN_AUTO                                              0        0      0     0
# AUTO_RUS_FL                                           0        0      0     0
# HS_PRESENCE_FL                                        0        0      0     0
# COT_PRESENCE_FL                                       0        0      0     0
# GAR_PRESENCE_FL                                       0        0      0     0
# LAND_PRESENCE_FL                                      0        0      0     0
# CREDIT                                            13065  13824.2   8900  8590
# TERM                                                  6        5      3    12
# FST_PAYMENT                                       10000    10239   1000  5000
# DL_DOCUMENT_FL                                        0        0      0     0
# GPF_DOCUMENT_FL                                       0        1      1     0
# FACT_LIVING_TERM                                     36       84    300    24
# WORK_TIME                                            84        0    444   144
# FACT_PHONE_FL                                         0        0      0     1
# REG_PHONE_FL                                          0        0      0     0
# GEN_PHONE_FL                                          1        0      1     1
# ...                                                 ...      ...    ...   ...
# REG_ADDRESS_PROVINCE_Псковская область                0        0      0     0
# REG_ADDRESS_PROVINCE_Ростовская область               0        0      0     0
# REG_ADDRESS_PROVINCE_Рязанская область                0        0      0     0
# REG_ADDRESS_PROVINCE_Самарская область                0        0      0     0
# REG_ADDRESS_PROVINCE_Санкт-Петербург                  0        0      0     0
# REG_ADDRESS_PROVINCE_Саратовская область              0        0      0     0
# REG_ADDRESS_PROVINCE_Сахалинская область              0        0      0     0
# REG_ADDRESS_PROVINCE_Свердловская область             0        0      0     0
# REG_ADDRESS_PROVINCE_Северная Осетия                  0        0      0     0
# REG_ADDRESS_PROVINCE_Смоленская область               0        0      0     0
# REG_ADDRESS_PROVINCE_Ставропольский край              0        0      0     0
# REG_ADDRESS_PROVINCE_Тамбовская область               0        0      0     0
# REG_ADDRESS_PROVINCE_Татарстан                        0        0      0     0
# REG_ADDRESS_PROVINCE_Тверская область                 0        0      0     0
# REG_ADDRESS_PROVINCE_Томская область                  0        0      0     1
# REG_ADDRESS_PROVINCE_Тульская область                 0        0      0     0
# REG_ADDRESS_PROVINCE_Тюменская область                0        0      0     0
# REG_ADDRESS_PROVINCE_Удмуртия                         0        0      0     0
# REG_ADDRESS_PROVINCE_Ульяновская область              0        0      0     0
# REG_ADDRESS_PROVINCE_Усть-Ордынский Бурятский АО      0        0      0     0
# REG_ADDRESS_PROVINCE_Хабаровский край                 1        0      0     0
# REG_ADDRESS_PROVINCE_Хакасия                          0        0      0     0
# REG_ADDRESS_PROVINCE_Ханты-Мансийский АО              0        0      0     0
# REG_ADDRESS_PROVINCE_Челябинская область              0        0      0     0
# REG_ADDRESS_PROVINCE_Читинская область                0        0      0     0
# REG_ADDRESS_PROVINCE_Чувашия                          0        0      0     0
# REG_ADDRESS_PROVINCE_Эвенкийский АО                   0        0      0     0
# REG_ADDRESS_PROVINCE_Якутия                           0        0      0     0
# REG_ADDRESS_PROVINCE_Ямало-Ненецкий АО                0        0      0     0
# REG_ADDRESS_PROVINCE_Ярославская область              0        0      0     0
#
#                                                   8     9      ...    30123  \
# TARGET                                                0     1  ...        1
# AGE                                                  53    33  ...       36
# SOCSTATUS_WORK_FL                                     0     1  ...        1
# SOCSTATUS_PENS_FL                                     1     0  ...        0
# GENDER                                                1     0  ...        0
# CHILD_TOTAL                                           2     1  ...        0
# DEPENDANTS                                            0     0  ...        0
# PERSONAL_INCOME                                    9000  4000  ...    15000
# REG_FACT_FL                                           1     1  ...        0
# FACT_POST_FL                                          1     1  ...        1
# REG_POST_FL                                           1     1  ...        0
# REG_FACT_POST_FL                                      1     1  ...        0
# REG_FACT_POST_TP_FL                                   1     1  ...        1
# FL_PRESENCE_FL                                        0     0  ...        0
# OWN_AUTO                                              0     0  ...        0
# AUTO_RUS_FL                                           0     0  ...        0
# HS_PRESENCE_FL                                        0     1  ...        1
# COT_PRESENCE_FL                                       0     0  ...        0
# GAR_PRESENCE_FL                                       0     0  ...        0
# LAND_PRESENCE_FL                                      0     0  ...        0
# CREDIT                                            12521  6903  ...    28230
# TERM                                                  5     6  ...       10
# FST_PAYMENT                                         659   767  ...     3150
# DL_DOCUMENT_FL                                        0     0  ...        0
# GPF_DOCUMENT_FL                                       0     0  ...        0
# FACT_LIVING_TERM                                    276    65  ...       72
# WORK_TIME                                             0    36  ...       48
# FACT_PHONE_FL                                         1     1  ...        1
# REG_PHONE_FL                                          0     0  ...        0
# GEN_PHONE_FL                                          0     1  ...        1
# ...                                                 ...   ...  ...      ...
# REG_ADDRESS_PROVINCE_Псковская область                0     0  ...        0
# REG_ADDRESS_PROVINCE_Ростовская область               0     0  ...        0
# REG_ADDRESS_PROVINCE_Рязанская область                0     0  ...        0
# REG_ADDRESS_PROVINCE_Самарская область                0     0  ...        0
# REG_ADDRESS_PROVINCE_Санкт-Петербург                  0     0  ...        0
# REG_ADDRESS_PROVINCE_Саратовская область              0     0  ...        0
# REG_ADDRESS_PROVINCE_Сахалинская область              0     0  ...        0
# REG_ADDRESS_PROVINCE_Свердловская область             0     0  ...        0
# REG_ADDRESS_PROVINCE_Северная Осетия                  0     0  ...        0
# REG_ADDRESS_PROVINCE_Смоленская область               0     0  ...        0
# REG_ADDRESS_PROVINCE_Ставропольский край              0     0  ...        0
# REG_ADDRESS_PROVINCE_Тамбовская область               0     0  ...        0
# REG_ADDRESS_PROVINCE_Татарстан                        0     0  ...        0
# REG_ADDRESS_PROVINCE_Тверская область                 0     0  ...        0
# REG_ADDRESS_PROVINCE_Томская область                  0     0  ...        0
# REG_ADDRESS_PROVINCE_Тульская область                 0     0  ...        0
# REG_ADDRESS_PROVINCE_Тюменская область                0     0  ...        0
# REG_ADDRESS_PROVINCE_Удмуртия                         0     0  ...        0
# REG_ADDRESS_PROVINCE_Ульяновская область              0     0  ...        0
# REG_ADDRESS_PROVINCE_Усть-Ордынский Бурятский АО      0     0  ...        0
# REG_ADDRESS_PROVINCE_Хабаровский край                 0     0  ...        0
# REG_ADDRESS_PROVINCE_Хакасия                          0     0  ...        0
# REG_ADDRESS_PROVINCE_Ханты-Мансийский АО              0     0  ...        0
# REG_ADDRESS_PROVINCE_Челябинская область              0     0  ...        0
# REG_ADDRESS_PROVINCE_Читинская область                0     0  ...        0
# REG_ADDRESS_PROVINCE_Чувашия                          0     0  ...        0
# REG_ADDRESS_PROVINCE_Эвенкийский АО                   0     0  ...        0
# REG_ADDRESS_PROVINCE_Якутия                           0     0  ...        0
# REG_ADDRESS_PROVINCE_Ямало-Ненецкий АО                0     0  ...        0
# REG_ADDRESS_PROVINCE_Ярославская область              0     0  ...        0
#
#                                                  30124  30125  30126  30127  \
# TARGET                                               0      0      0      0
# AGE                                                 31     35     61     39
# SOCSTATUS_WORK_FL                                    1      1      1      1
# SOCSTATUS_PENS_FL                                    0      0      0      0
# GENDER                                               1      1      0      1
# CHILD_TOTAL                                          1      1      0      1
# DEPENDANTS                                           1      1      0      1
# PERSONAL_INCOME                                   8100   9500  13000  10000
# REG_FACT_FL                                          1      0      1      1
# FACT_POST_FL                                         1      1      1      1
# REG_POST_FL                                          1      0      1      1
# REG_FACT_POST_FL                                     1      0      1      1
# REG_FACT_POST_TP_FL                                  1      0      1      1
# FL_PRESENCE_FL                                       1      0      0      0
# OWN_AUTO                                             0      1      1      0
# AUTO_RUS_FL                                          0      0      1      0
# HS_PRESENCE_FL                                       0      0      1      0
# COT_PRESENCE_FL                                      0      0      0      0
# GAR_PRESENCE_FL                                      0      0      0      0
# LAND_PRESENCE_FL                                     0      0      1      0
# CREDIT                                            7920  18426  17254  22930
# TERM                                                 6     12      6      6
# FST_PAYMENT                                        880   2050   2000   2550
# DL_DOCUMENT_FL                                       0      0      0      0
# GPF_DOCUMENT_FL                                      0      0      1      1
# FACT_LIVING_TERM                                   156    120     84    156
# WORK_TIME                                           96    120    132    108
# FACT_PHONE_FL                                        0      0      1      0
# REG_PHONE_FL                                         0      0      1      0
# GEN_PHONE_FL                                         1      1      1      1
# ...                                                ...    ...    ...    ...
# REG_ADDRESS_PROVINCE_Псковская область               0      0      0      0
# REG_ADDRESS_PROVINCE_Ростовская область              0      0      0      0
# REG_ADDRESS_PROVINCE_Рязанская область               0      0      0      0
# REG_ADDRESS_PROVINCE_Самарская область               0      0      0      0
# REG_ADDRESS_PROVINCE_Санкт-Петербург                 0      0      0      0
# REG_ADDRESS_PROVINCE_Саратовская область             0      0      0      0
# REG_ADDRESS_PROVINCE_Сахалинская область             0      0      0      0
# REG_ADDRESS_PROVINCE_Свердловская область            0      0      0      0
# REG_ADDRESS_PROVINCE_Северная Осетия                 0      0      0      0
# REG_ADDRESS_PROVINCE_Смоленская область              0      0      0      0
# REG_ADDRESS_PROVINCE_Ставропольский край             0      0      0      0
# REG_ADDRESS_PROVINCE_Тамбовская область              0      0      0      1
# REG_ADDRESS_PROVINCE_Татарстан                       0      0      0      0
# REG_ADDRESS_PROVINCE_Тверская область                0      0      0      0
# REG_ADDRESS_PROVINCE_Томская область                 0      0      0      0
# REG_ADDRESS_PROVINCE_Тульская область                0      0      0      0
# REG_ADDRESS_PROVINCE_Тюменская область               0      0      0      0
# REG_ADDRESS_PROVINCE_Удмуртия                        0      0      0      0
# REG_ADDRESS_PROVINCE_Ульяновская область             0      1      0      0
# REG_ADDRESS_PROVINCE_Усть-Ордынский Бурятский АО     0      0      0      0
# REG_ADDRESS_PROVINCE_Хабаровский край                0      0      0      0
# REG_ADDRESS_PROVINCE_Хакасия                         0      0      0      0
# REG_ADDRESS_PROVINCE_Ханты-Мансийский АО             0      0      0      0
# REG_ADDRESS_PROVINCE_Челябинская область             0      0      0      0
# REG_ADDRESS_PROVINCE_Читинская область               0      0      0      0
# REG_ADDRESS_PROVINCE_Чувашия                         0      0      0      0
# REG_ADDRESS_PROVINCE_Эвенкийский АО                  0      0      0      0
# REG_ADDRESS_PROVINCE_Якутия                          0      0      0      0
# REG_ADDRESS_PROVINCE_Ямало-Ненецкий АО               0      0      0      0
# REG_ADDRESS_PROVINCE_Ярославская область             0      0      0      0
#
#                                                   30128  30129 30130  30131  \
# TARGET                                                0      0     0      0
# AGE                                                  25     51    22     60
# SOCSTATUS_WORK_FL                                     1      1     1      0
# SOCSTATUS_PENS_FL                                     0      0     0      1
# GENDER                                                0      1     1      1
# CHILD_TOTAL                                           1      2     1      2
# DEPENDANTS                                            1      0     1      0
# PERSONAL_INCOME                                   12000  10000  6000   4500
# REG_FACT_FL                                           0      1     1      1
# FACT_POST_FL                                          0      1     1      1
# REG_POST_FL                                           1      1     1      1
# REG_FACT_POST_FL                                      0      1     1      1
# REG_FACT_POST_TP_FL                                   1      0     1      1
# FL_PRESENCE_FL                                        0      0     0      1
# OWN_AUTO                                              0      0     0      0
# AUTO_RUS_FL                                           0      0     0      0
# HS_PRESENCE_FL                                        0      0     0      0
# COT_PRESENCE_FL                                       0      0     0      0
# GAR_PRESENCE_FL                                       0      0     0      0
# LAND_PRESENCE_FL                                      0      0     0      0
# CREDIT                                            13450   8991  2700  24357
# TERM                                                 10      6     6     10
# FST_PAYMENT                                        1500   4000   800  17930
# DL_DOCUMENT_FL                                        0      0     0      0
# GPF_DOCUMENT_FL                                       0      1     1      0
# FACT_LIVING_TERM                                    121    300    48    270
# WORK_TIME                                            48    156    48      0
# FACT_PHONE_FL                                         0      1     0      1
# REG_PHONE_FL                                          0      0     0      0
# GEN_PHONE_FL                                          1      1     1      0
# ...                                                 ...    ...   ...    ...
# REG_ADDRESS_PROVINCE_Псковская область                0      0     0      0
# REG_ADDRESS_PROVINCE_Ростовская область               0      0     0      0
# REG_ADDRESS_PROVINCE_Рязанская область                0      0     0      0
# REG_ADDRESS_PROVINCE_Самарская область                0      0     0      0
# REG_ADDRESS_PROVINCE_Санкт-Петербург                  0      0     0      0
# REG_ADDRESS_PROVINCE_Саратовская область              0      0     0      0
# REG_ADDRESS_PROVINCE_Сахалинская область              0      0     0      0
# REG_ADDRESS_PROVINCE_Свердловская область             0      0     0      0
# REG_ADDRESS_PROVINCE_Северная Осетия                  0      0     0      0
# REG_ADDRESS_PROVINCE_Смоленская область               0      0     0      0
# REG_ADDRESS_PROVINCE_Ставропольский край              0      0     0      0
# REG_ADDRESS_PROVINCE_Тамбовская область               0      0     0      0
# REG_ADDRESS_PROVINCE_Татарстан                        0      0     0      0
# REG_ADDRESS_PROVINCE_Тверская область                 0      0     0      0
# REG_ADDRESS_PROVINCE_Томская область                  0      0     0      0
# REG_ADDRESS_PROVINCE_Тульская область                 0      0     0      0
# REG_ADDRESS_PROVINCE_Тюменская область                0      0     0      0
# REG_ADDRESS_PROVINCE_Удмуртия                         0      0     0      0
# REG_ADDRESS_PROVINCE_Ульяновская область              0      0     0      0
# REG_ADDRESS_PROVINCE_Усть-Ордынский Бурятский АО      0      0     0      0
# REG_ADDRESS_PROVINCE_Хабаровский край                 0      0     0      0
# REG_ADDRESS_PROVINCE_Хакасия                          0      0     0      0
# REG_ADDRESS_PROVINCE_Ханты-Мансийский АО              0      0     0      0
# REG_ADDRESS_PROVINCE_Челябинская область              0      0     0      0
# REG_ADDRESS_PROVINCE_Читинская область                0      0     0      0
# REG_ADDRESS_PROVINCE_Чувашия                          0      0     0      0
# REG_ADDRESS_PROVINCE_Эвенкийский АО                   0      0     0      0
# REG_ADDRESS_PROVINCE_Якутия                           0      0     0      0
# REG_ADDRESS_PROVINCE_Ямало-Ненецкий АО                0      0     0      0
# REG_ADDRESS_PROVINCE_Ярославская область              0      0     0      0
#
#                                                   30132
# TARGET                                                0
# AGE                                                  37
# SOCSTATUS_WORK_FL                                     1
# SOCSTATUS_PENS_FL                                     0
# GENDER                                                0
# CHILD_TOTAL                                           2
# DEPENDANTS                                            0
# PERSONAL_INCOME                                   20000
# REG_FACT_FL                                           1
# FACT_POST_FL                                          1
# REG_POST_FL                                           1
# REG_FACT_POST_FL                                      1
# REG_FACT_POST_TP_FL                                   0
# FL_PRESENCE_FL                                        0
# OWN_AUTO                                              0
# AUTO_RUS_FL                                           0
# HS_PRESENCE_FL                                        0
# COT_PRESENCE_FL                                       0
# GAR_PRESENCE_FL                                       0
# LAND_PRESENCE_FL                                      0
# CREDIT                                            10245
# TERM                                                  6
# FST_PAYMENT                                        1200
# DL_DOCUMENT_FL                                        0
# GPF_DOCUMENT_FL                                       0
# FACT_LIVING_TERM                                    432
# WORK_TIME                                            36
# FACT_PHONE_FL                                         0
# REG_PHONE_FL                                          0
# GEN_PHONE_FL                                          1
# ...                                                 ...
# REG_ADDRESS_PROVINCE_Псковская область                0
# REG_ADDRESS_PROVINCE_Ростовская область               0
# REG_ADDRESS_PROVINCE_Рязанская область                0
# REG_ADDRESS_PROVINCE_Самарская область                0
# REG_ADDRESS_PROVINCE_Санкт-Петербург                  0
# REG_ADDRESS_PROVINCE_Саратовская область              0
# REG_ADDRESS_PROVINCE_Сахалинская область              0
# REG_ADDRESS_PROVINCE_Свердловская область             0
# REG_ADDRESS_PROVINCE_Северная Осетия                  0
# REG_ADDRESS_PROVINCE_Смоленская область               0
# REG_ADDRESS_PROVINCE_Ставропольский край              0
# REG_ADDRESS_PROVINCE_Тамбовская область               0
# REG_ADDRESS_PROVINCE_Татарстан                        0
# REG_ADDRESS_PROVINCE_Тверская область                 0
# REG_ADDRESS_PROVINCE_Томская область                  0
# REG_ADDRESS_PROVINCE_Тульская область                 0
# REG_ADDRESS_PROVINCE_Тюменская область                0
# REG_ADDRESS_PROVINCE_Удмуртия                         0
# REG_ADDRESS_PROVINCE_Ульяновская область              0
# REG_ADDRESS_PROVINCE_Усть-Ордынский Бурятский АО      0
# REG_ADDRESS_PROVINCE_Хабаровский край                 0
# REG_ADDRESS_PROVINCE_Хакасия                          0
# REG_ADDRESS_PROVINCE_Ханты-Мансийский АО              0
# REG_ADDRESS_PROVINCE_Челябинская область              0
# REG_ADDRESS_PROVINCE_Читинская область                0
# REG_ADDRESS_PROVINCE_Чувашия                          0
# REG_ADDRESS_PROVINCE_Эвенкийский АО                   0
# REG_ADDRESS_PROVINCE_Якутия                           0
# REG_ADDRESS_PROVINCE_Ямало-Ненецкий АО                0
# REG_ADDRESS_PROVINCE_Ярославская область              0
#
# [203 rows x 30133 columns]

# %%
df_preproc.info() # не ясно почему не отображаются типы данных по столбцам
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Columns: 203 entries, TARGET to REG_ADDRESS_PROVINCE_Ярославская область
# dtypes: float64(7), int64(31), object(1), uint8(164)
# memory usage: 13.7+ MB

# %% [markdown]
# #### Задание 4. Отделите целевую переменную и остальные признаки
#
# Должно получится:
# * 2 матрицы: X и X_test
# * 2 вектора: y и y_test

# %%
y = df_train_preproc['TARGET']
X = df_train_preproc.drop(['TARGET'], axis=1)
y_test = df_test_preproc['TARGET']
X_test = df_test_preproc.drop(['TARGET'], axis=1)

# %% [markdown]
# #### Задание 5. Обучение и оценка качества разных моделей

# %%
from sklearn.cross_validation import train_test_split
# test_size=0.3, random_state=42

X_train, X_train_test, y_train, y_train_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Попробовать следующие "черные ящики": интерфейс одинаковый 
#     fit, 
#     predict, 
#     predict_proba

from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)
predict_dtc = dtc.predict(X_train_test)

from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
predict_rfc = rfc.predict(X_train_test)

from sklearn.linear_model import LogisticRegression

# %%
predict_rfc
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall

from sklearn.metrics import accuracy_score, precision_score, recall_score
results_dtc = []
print('precision DTC', precision_score(y_train_test, predict_dtc))
print('recall DTC', recall_score(y_train_test, predict_dtc))
print('accuracy DTC', accuracy_score(y_train_test, predict_dtc))
results_dtc.append(precision_score(y_train_test, predict_dtc))
results_dtc.append(recall_score(y_train_test, predict_dtc))
results_dtc.append(accuracy_score(y_train_test, predict_dtc))
print(results_dtc, '\n')

results_rfc = []
print('precision RFC', precision_score(y_train_test, predict_rfc))
print('recall RFC', recall_score(y_train_test, predict_rfc))
print('accuracy RFC', accuracy_score(y_train_test, predict_rfc))
results_rfc.append(precision_score(y_train_test, predict_rfc))
results_rfc.append(recall_score(y_train_test, predict_rfc))
results_rfc.append(accuracy_score(y_train_test, predict_rfc))
print(results_rfc, '\n')
# Out:
# precision DTC 0.16055846422338568
# recall DTC 0.16576576576576577
# accuracy DTC 0.7932997591416685
# [0.16055846422338568, 0.16576576576576577, 0.7932997591416685]
#
# precision RFC 0.2727272727272727
# recall RFC 0.010810810810810811
# accuracy RFC 0.8762864024523758
# [0.2727272727272727, 0.010810810810810811, 0.8762864024523758]

# %%
predict_dtc
# Out:
# array([1, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
# Визуалищировать эти метрики всех моделей на одном графике (чтоб визуально посмотреть)

plt.bar(range(3), results_dtc)
plt.show()
plt.bar(range(3), results_rfc)
plt.show()

# %%
# Потроить roc-кривые всех можелей на одном графике
# Вывести roc_auc каждой моделе

from sklearn.metrics import roc_auc_score, roc_curve

fpr, tpr, thresholds = roc_curve(y_train_test, predict_dtc)
plt.figure(figsize=(5, 5))
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1])
plt.ylabel('tpr')
plt.xlabel('fpr')
plt.grid(True)
plt.title('ROC curve')
plt.xlim((-0.01, 1.01))
plt.ylim((-0.01, 1.01))
# Out:
# (-0.01, 1.01)

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import StratifiedKFold
# Сделать k-fold (10 фолдов) кросс-валидацию каждой модели
# И посчитать средний roc_auc
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=123)

## Your Code Here

# %%
# Взять лучшую модель и сделать predict (с вероятностями (!!!)) для test выборки


## Your Code Here

# %%
# Померить roc_auc на тесте
